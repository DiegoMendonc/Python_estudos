# %%
import pandas as pd
import numpy as np

# %%
df_teste = pd.read_excel('vendas_ficticias.xlsx')

display(df_teste)
# Out:
#       SKU  Quantidade Vendida Data Vendida
# 0    SKU1                  49   2024-11-26
# 1    SKU1                  92   2024-10-23
# 2    SKU1                  80   2024-11-09
# 3    SKU1                  77   2024-09-27
# 4    SKU1                  43   2024-11-02
# ..    ...                 ...          ...
# 115  SKU4                  29   2024-10-09
# 116  SKU4                  98   2024-12-16
# 117  SKU4                  87   2024-10-27
# 118  SKU4                  98   2024-11-09
# 119  SKU4                  20   2024-11-10
#
# [120 rows x 3 columns]
